# %%
import pandas as pd
import plotly.express as px

# %%
recall_per_number_of_samples_df = pd.read_csv("recall_per_number_of_samples.csv")
recall_per_number_of_samples_df
# Out:
#     coverage                                         tool  coverage_threshold  \
# 0       100x  pandora_illumina_nodenovo_global_genotyping                   0
# 1       100x  pandora_illumina_nodenovo_global_genotyping                   0
# 2       100x  pandora_illumina_nodenovo_global_genotyping                   0
# 3       100x  pandora_illumina_nodenovo_global_genotyping                   0
# 4       100x  pandora_illumina_nodenovo_global_genotyping                   0
# ..       ...                                          ...                 ...
# 616     100x                         snippy_NZ_NG941718.1                   0
# 617     100x                         snippy_NZ_NG941718.1                   0
# 618     100x                         snippy_NZ_NG941718.1                   0
# 619     100x                         snippy_NZ_NG941718.1                   0
# 620     100x                         snippy_NZ_NG941718.1                   0
#
# ...

# %%
fig = px.line(recall_per_number_of_samples_df, x="NB_OF_SAMPLES", y="recall", color='tool')
fig.update_layout(
    xaxis = dict(
        tickmode = 'linear',
        tick0 = 2,
        dtick = 1
    ),
    yaxis_title="Recall",
    xaxis_title="Number of samples",
)
# Out:
# <div>
#
#
#             <div id="c97e5918-d936-404c-80fc-8360078913c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c97e5918-d936-404c-80fc-8360078913c3")) {
#                     Plotly.newPlot(
#                         'c97e5918-d936-404c-80fc-8360078913c3',
# ...

# %%
import chart_studio.plotly as chart_studio
chart_studio.plot(fig, filename = 'pandora_and_snippy_recall_breakdown_24_way_illumina_100x', auto_open=True)
# Out:
# 'https://plotly.com/~leandro.ishi.lima/16/'
