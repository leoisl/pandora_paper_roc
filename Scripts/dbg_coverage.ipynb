# %%
import os
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
FIGSIZE = (11.69, 8.27)

# %%
filedir = "../mccortex_graphs/padding_10/cleaned/"
filename = "loman_k12_merged_pass.mm2.sorted_1196-1216_mccortex_K9_tips_cleaned_unitig2_double_kmer_covg_after.csv"
filepath = os.path.join(filedir, filename)
df = pd.read_csv(filepath)

# %%
print(df.columns)
# Out:
# Index(['Covg', 'NumKmers', 'NumUnitigs'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=FIGSIZE)
# df.Covg = np.log10(df.Covg)
# df.NumKmers = np.log10(df.NumKmers)
p = sns.barplot(x=df.Covg, y=df.NumKmers, color='r', ax=ax)
# p.set_yscale('log')
# p.set_xscale('log')

# %%
filename = "loman_k12_merged_pass.mm2.sorted_1196-1216_mccortex_K9_tips_cleaned_unitig2_double_kmer_covg_before.csv"
filepath = os.path.join(filedir, filename)
df = pd.read_csv(filepath)
fig, ax = plt.subplots(figsize=FIGSIZE)
# df.Covg = np.log10(df.Covg)
# df.NumKmers = np.log10(df.NumKmers)
p = sns.barplot(x=df.Covg, y=df.NumKmers, color='r', ax=ax)

# %%
filename = "loman_k12_merged_pass.mm2.sorted_1196-1216_mccortex_K7_tips_cleaned_unitig2_double_kmer_covg_before.csv"
filepath = os.path.join(filedir, filename)
df = pd.read_csv(filepath)
fig, ax = plt.subplots(figsize=FIGSIZE)
# df.Covg = np.log10(df.Covg)
df.NumKmers = np.log10(df.NumKmers)
p = sns.barplot(x=df.Covg, y=df.NumKmers, color='r', ax=ax)

# %%
filename = "loman_k12_merged_pass.mm2.sorted_1196-1216_mccortex_K7_tips_cleaned_unitig2_double_kmer_covg_after.csv"
filepath = os.path.join(filedir, filename)
df = pd.read_csv(filepath)
fig, ax = plt.subplots(figsize=FIGSIZE)
df.Covg = np.log10(df.Covg)
df.NumKmers = np.log10(df.NumKmers)
p = sns.barplot(x=df.Covg, y=df.NumKmers, color='r', ax=ax)

# %%
filename = "loman_k12_merged_pass.mm2.sorted_1196-1216_mccortex_K11_tips_cleaned_unitig2_double_kmer_covg_before.csv"
filepath = os.path.join(filedir, filename)
df = pd.read_csv(filepath)
fig, ax = plt.subplots(figsize=FIGSIZE)
df.Covg = np.log10(df.Covg)
df.NumKmers = np.log10(df.NumKmers)
p = sns.barplot(x=df.Covg, y=df.NumKmers, color='r', ax=ax)

# %%
filename = "loman_k12_merged_pass.mm2.sorted_1196-1216_mccortex_K7_tips_cleaned_unitig2_double_kmer_covg_after.csv"
filepath = os.path.join(filedir, filename)
df = pd.read_csv(filepath)
fig, ax = plt.subplots(figsize=FIGSIZE)
df.Covg = np.log10(df.Covg)
df.NumKmers = np.log10(df.NumKmers)
p = sns.barplot(x=df.Covg, y=df.NumKmers, color='r', ax=ax)
